# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Photo
known_classes = [8, 6, 4, 2, 0]
#pown
all_test_acc_pown = [0.7830344827586206, 0.44675862068965516, 0.27227586206896554, 0.40579310344827585, 0.26082758620689656]
#GCN
all_test_acc_gcn = [0.5099310344827587, 0.3703448275862069, 0.27227586206896554, 0.26082758620689656, 0.40606896551724136]
#OWGL
all_test_acc_owgl = [0.6895172413793104, 0.6044137931034482, 0.528, 0.3099310344827586, 0.1674]

# %%
# Create a seaborn lineplot with the 'hue' parameter for the legend
sns.lineplot(x=known_classes, y=all_test_acc_pown, label='POWN')
sns.lineplot(x=known_classes, y=all_test_acc_gcn, label='GCN')
sns.lineplot(x=known_classes, y=all_test_acc_owgl, label='OpenWGL')

# Set the x and y labels
plt.xlabel('Number of known classes')
plt.ylabel('Performance of the method')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
#OGB-arxiv
known_classes = [40, 32, 24, 16, 8, 0]
#pown
all_test_acc_pown = [0.6263399378639178, 0.4921918400098759, 0.5838322737279592, 0.5313458016994835, 0.41439828817151203, 0.47818035923708413]
#GCN
all_test_acc_gcn = [0.2209740139497562, 0.2209740139497562, 0.2209740139497562, 0.2209740139497562, 0.2309740139497562]
#OWGL
all_test_acc_owgl = [0.04804230191551962, 0.6044137931034482, 0.528, 0.3099310344827586, 0.1674]
